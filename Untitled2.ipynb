# %% [markdown]
# <a href="https://colab.research.google.com/github/gustavo0177/python-graficos/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import pandas as pd

data = [['a',10],['b',12],['c',15],['d',11],['e',14],['f',]]

df = pd.DataFrame(data, columns=['nome','IDADE'])

type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head(10)
# Out:
#   nome  IDADE
# 0    a   10.0
# 1    b   12.0
# 2    c   15.0
# 3    d   11.0
# 4    e   14.0
# 5    f    NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   nome    6 non-null      object
#  1   IDADE   5 non-null      float64
# dtypes: float64(1), object(1)
# memory usage: 228.0+ bytes

# %%
df.describe()
# Out:
#            IDADE
# count   5.000000
# mean   12.400000
# std     2.073644
# min    10.000000
# 25%    11.000000
# 50%    12.000000
# 75%    14.000000
# max    15.000000

# %%
select = df[df['IDADE'].notnull()]

# %%
select.head(10)
# Out:
#   nome  IDADE
# 0    a   10.0
# 1    b   12.0
# 2    c   15.0
# 3    d   11.0
# 4    e   14.0

# %%
select.describe()
# Out:
#            IDADE
# count   5.000000
# mean   12.400000
# std     2.073644
# min    10.000000
# 25%    11.000000
# 50%    12.000000
# 75%    14.000000
# max    15.000000

# %%
plt.boxplot(select['IDADE']);
