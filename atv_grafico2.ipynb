# %% [markdown]
# <a href="https://colab.research.google.com/github/gustavo0177/python-graficos/blob/main/atv_grafico2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
dias_semanas = ['segunda-feira', 'terça-feira','quarta-feira','quinta-feira','sexta-feira','sabado','domingo']

type(dias_semanas)
# Out:
# list

# %%
dias_semanas[1]
# Out:
# 'terça-feira'

# %%
quantidade = [30,50,86,9,45,70,12]
quantidade
# Out:
# [30, 50, 86, 9, 45, 70, 12]

# %%
type(quantidade)
# Out:
# list

# %%
plt.bar (dias_semanas,quantidade);

# %%
plt.xticks(rotation=45)
plt.bar (dias_semanas,quantidade)
# Out:
# <BarContainer object of 7 artists>
