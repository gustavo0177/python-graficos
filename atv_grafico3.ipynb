# %% [markdown]
# <a href="https://colab.research.google.com/github/gustavo0177/python-graficos/blob/main/atv_grafico3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import pandas as pd

data = [['a',10], ['b',12], ['c',15], ['d',11], ['e',14], ['f',60]]

df = pd.DataFrame(data, columns=['nomes', 'idade'])

type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head(10)
# Out:
#   nomes  idade
# 0     a     10
# 1     b     12
# 2     c     15
# 3     d     11
# 4     e     14
# 5     f     60

# %%
plt.boxplot(df['idade']);

# %%
import matplotlib.pyplot as plt
import pandas as pd

data = [['a',10], ['b',12], ['c',15], ['d',11], ['e',14]]

df = pd.DataFrame(data, columns=['nomes', 'idade'])

type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
plt.boxplot(df['idade'],labels=['idade dos individos']);
# Out:
# /tmp/ipython-input-17-2151057764.py:1: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(df['idade'],labels=['idade dos individos']);
